# %% [markdown]
# # Tasks

# %% [markdown]
# ## Task 1: Source the data set

# %% [markdown]
# # Question -- Import the Iris data set from the sklearn.datasets module

# %%
# firstly import the pandas function to read comma seperated values (csv), which will be in the data set
# rename to pd for short

import pandas as pd

# import the sklearn package which is a machine learning libraries for Python.good for practicing on datasets.
# rename to skl for short

import sklearn as skl

#load the iris dataset
#df is a pandas fuction that will display dataframe

df=pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# df to display
df


#Reference: pandas- "https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html"
#Reference: Ian McLoughlin Lecture : week 3 practical-pands and loading datasets
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # question:  Explain, in your own words, what the load_iris() function returns.

# %% [markdown]
# load_iris() is a panda function that enables you to load in data from Scikit-learn , and you can then chose what specific data you would like to be displayed like in the example below with "feature_names"
#
# "load_iris() is a a quick way to load the popular iris dataset from Scikit-learn and it is used to practicing classification algorithms and exploratory data analysis."
# Reference: chatgpt- prompt-explain load_iris(), "https://chatgpt.com/c/6813ac34-43f0-8003-b08c-170c373f4fb8"
#
# Reference: Ian McLoughlin Lecture : week 3 practical-pands and loading datasets

# %%
import pandas as pd
import sklearn as skl
from sklearn.datasets import load_iris

#how to display the dataset imported-
#rename function to iris

iris = load_iris()

#example of displaying information from set like feature names

print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %% [markdown]
# ## Task 2: Explore the data structure.

# %% [markdown]
# ## question -Print and explain the shape of the data set, the first and last 5 rows of the data, the feature names, and the target classes.

# %%
# to do this i will need to use other panda functions
# all which can be found on the pandas website- Reference: "https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html"
# also Chatgpt:prompt- to get the last five rows, "https://chatgpt.com/c/6813ac34-43f0-8003-b08c-170c373f4fb8"

# for the last 5 rows use : print to display, df for dataframe, and for the last 5 rows - .tail() function

print(df.tail())
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# explaining the data shown- in last 5 rows as shown above the function is displaying the last 5 rows of data from specimen 145 to 149 , aslo includes the column for values in length, width for sepal and length and width for petal , also the species column

# %% [markdown]
# same as above but for the feature name, also from the same sources- iris.feature_names function

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# explaining the data shown- sepal length and width and petal length and width in centimetres are the feature names

# %% [markdown]
# same as above but for the target classes, also from the same sources-iris.target_names function

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# explaining the data shown- array is all the target names(classes) in the dataset which in this case are setosa,versicolor and virginica

# %% [markdown]
# ## Task 3: summarize the data

# %% [markdown]
# ## Question -  For each feature in the dataset, calculate and display:
#
# - mean
# -minimum
# -maximum
# -standard deviation
# -median

# %% [markdown]
# "NumPy (short for Numerical Python) is a popular open-source Python library that's mainly used for working with numerical data. It provides powerful tools for handling large, multi-dimensional arrays and matrices, along with a huge collection of mathematical functions to operate on these arrays efficiently." Reference chatgpt- prompt, what is numPy, "https://chatgpt.com/c/6813c8eb-44bc-8003-94bb-968f3aa2c8dc
#
# firstly import numPy as we are working with large array of data , will also rename to np for short:

# %%
import numpy as np

# for mean use numPy mean() function

# all information gathered for this question referenced below
# reference: chatgpt: prompt -how to get the mean of the iris dataset, "https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046".
# reference: W3schools (2025), machine learning-mean, median and mode [online] 
# Available at: https://www.w3schools.com/python/python_ml_mean_median_mode.asp. [accessed 01 may 2025].
# Reference: geeksforgeeks.com (2025) Pandas Functions in Python: A Toolkit for Data Analysis. [online]
# Available from: https://www.geeksforgeeks.org/pandas-functions-in-python/ [accessed 1 may 2025].


df = pd.DataFrame(iris.data, columns=iris.feature_names)

# apply
mean_values = df.mean()

#display
print(mean_values)
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# dtype: float64

# %%
# for minimum value: use .min() function pandas

#apply
min_values = df.min()


#display
print("Minimum values:", min_values)
# Out:
# Minimum values: sepal length (cm)    4.3
# sepal width (cm)     2.0
# petal length (cm)    1.0
# petal width (cm)     0.1
# dtype: float64

# %%
# for maximum value: .max() function pandas

#apply
max_values = df.max()

#display
print("Maximum values:", max_values)
# Out:
# Maximum values: sepal length (cm)    7.9
# sepal width (cm)     4.4
# petal length (cm)    6.9
# petal width (cm)     2.5
# dtype: float64

# %%
# for standard deviation: .std() function pandas

#apply
std_values = df.std()

#display
print("Standard Deviation:", std_values)
# Out:
# Standard Deviation: sepal length (cm)    0.828066
# sepal width (cm)     0.435866
# petal length (cm)    1.765298
# petal width (cm)     0.762238
# dtype: float64

# %%
# for median :.median() function pandas

#apply
median_values = df.median()

#display
print("Median values:", median_values)
# Out:
# Median values: sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# dtype: float64

# %% [markdown]
# ## Task 4. Visualize Features

# %% [markdown]
# ## Question 4. Plot histograms for each feature using matplotlib.
# ## Add appropriate titles and axis labels.

# %%
# import matplot library and change to plt for short
# also .hist() is a pandas built in function


import matplotlib.pyplot as plt

#Create histograms for each feature in the DataFrame

df.hist(figsize=(10, 8),color='pink', edgecolor='deeppink')

# this is to add big title or heading for the histogram
plt.suptitle("Histogram of Iris Dataset Features", fontsize=16)

# add this to stop the data display from overlapping
plt.tight_layout()

# this will show the plot
plt.show()

# %% [markdown]
# References for above:
# -Chatgpt: prompt- how would i plot a matplotlib for above data, "https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046"
#
# -matplotlib (2025), list of name colors/helper functions for plotting [online] Available from :https://matplotlib.org/stable/gallery/color/named_colors.html, [accessed 1 may 2025].

# %% [markdown]
# # Task 5.
#
# ## Investigate Relationships
#
# ## Question
#
# - Choose any two features from the data set and create a scatter plot of them.
#
# - Color-code the three different classes of the scatter plot points.

# %% [markdown]
# References:
#
# -chatgpt: prompt- Scatter Plot (two features) If you want to see how two features relate (like petal length vs petal width).
# Available at:https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046
#
# -matplotlib (2025), list of name colors/helper functions for plotting [online] Available from :https://matplotlib.org/stable/gallery/color/named_colors.html, [accessed 1 may 2025].
#
# -W3schools (2025) machine learning scatter plot [online] Available at: https://www.w3schools.com/python/python_ml_scatterplot.asp [ accessed 1 may 2025].
#
# -chatgpt - prompt- Color-code the three different classes of the scatter plot points , https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046

# %%
# scatter plot of Petal Length vs Petal Width for all the samples in the Iris dataset.

# Setting the figure size
plt.figure(figsize=(8,6))

# Scatter plot
plt.scatter(df["petal length (cm)"], df["petal width (cm)"], color='violet') 

# X-axis label
plt.xlabel("Petal Length (cm)")

# Y-axis label
plt.ylabel("Petal Width (cm)") 

# title of the scatter plot
plt.title("Petal Length vs Petal Width")
  
# to add in grid lines to make it easier to read of data
plt.grid(True)  

# display
plt.show()

# %% [markdown]
# Now to Color-code the three different classes of the scatter plot points.

# %%
# Add species labels to DataFrame
df['species'] = iris.target

# Define colors for each species
colors = ['plum', 'pink', 'mediumpurple']
species_names = iris.target_names

for i, color in enumerate(colors):
    subset = df[df['species'] == i]
    plt.scatter(subset["petal length (cm)"], subset["petal width (cm)"], 
                color=color, label=species_names[i])


# Add in the labels and title
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Petal Length vs Petal Width by Species")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Task 6: Analyze Relationship
#
# ## Question - Use numpy.polyfit to add a regression line to the scatter plot from Task 5.

# %% [markdown]
# References:
#
# -geeksforgeeks.org (2025). NumPy's polyfit Function : A Comprehensive Guide [online]. Available from: https://www.geeksforgeeks.org/numpys-polyfit-function-a-comprehensive-guide/. [accessed 1 may 2025].
#
# -chatgpt. prompt - use numpy.polyfit to add a regression line to the scatter plot, https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046

# %%
# will use numpy.polyfit to add regression line


# apply x and y variables
x = df["petal length (cm)"]
y = df["petal width (cm)"]

# Fit a linear regression line (degree=1)
coefficients = np.polyfit(x, y, 1)
slope, intercept = coefficients

# Create regression line values
regression_line = slope * x + intercept


# plot the regression line
plt.plot(x, regression_line, color='skyblue', label=f"y = {slope:.2f}x + {intercept:.2f}")


#add in labels and titles for the scatter plot
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Petal Length vs Petal Width with Regression Line")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Task 7: Analyze Class Distributions
# ## Create box-plots of the petal lengths for each of the three classes.

# %% [markdown]
# Reference:
#
# datacamp (2025) Python Boxplots: A Comprehensive Guide for Beginners [online] Available at :https://www.datacamp.com/tutorial/python-boxplots [accessed 04 may 2025
# ]
# Chatgpt - prompt : create a box plot of the petal length for each of the classes, https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046.

# %%
# firstly add species names for the boxplot
df['species'] = iris.target_names[iris.target]

# Preparadd in the data to be used for boxplot
data_to_plot = [df[df['species'] == species]["petal length (cm)"] for species in iris.target_names]

# Creating the boxplot
plt.figure(figsize=(8,6))
plt.boxplot(data_to_plot, labels=iris.target_names)
plt.title("Boxplot of Petal Lengths by Species")
plt.xlabel("Species")
plt.ylabel("Petal Length (cm)")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipykernel_1395/650955640.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_to_plot, labels=iris.target_names)

# %% [markdown]
# ## Task 8: Compute Correlations
#
# ## Calculate the correlation coefficients between the features.
# ## Display the results as a heatmap using matplotlib.

# %% [markdown]
# References:
#
# real python (2025).NumPy, SciPy, and pandas: Correlation With Python [online] Available at : https://realpython.com/numpy-scipy-pandas-correlation-python/#example-pandas-correlation-calculation. [accessed 04 may 2025].
#
# Chatgpt :prompt- Calculate the correlation coefficients between the features., https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046.

# %%
# Calculate the correlation coefficients between the features.


# Calculate correlation matrix by using the .corr pandas function 

correlation_matrix = df.corr()

# to display the output

print(correlation_matrix)
# Out:
#                    sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000

# %%
# Display the results as a heatmap using matplotlib.

import matplotlib.pyplot as plt

# import seaborn so we can visualize the data on a heatmap
import seaborn as sns


plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Iris Dataset Features")
plt.show()

# %% [markdown]
# Reference:
# Real Python (2025). Visualizing Data in Python With Seaborn [online].Available from: https://realpython.com/python-seaborn/. [accessed 4 May 2025].

# %% [markdown]
# ## Task 9: Fit a Simple Linear Regression
#
# ## For your two features in Task 5, calculate the coefficient of determination R 2 .
#
# ## Re-create the plot from Task 6 and annotate it with the R 2 value.

# %% [markdown]
# "The coefficient of determination R2R2 tells us how well one variable predicts another in a linear relationship.
# You can compute it manually from the correlation coefficient, since:
#
# R2=(r)2
#
# Where rr is the Pearson correlation coefficient between petal length and petal width."
#
# Reference : Chatgpt- prompt-for petal length and petal witdh calculate the coefficient of determination R 2, https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046.

# %%
# For your two features in Task 5, calculate the coefficient of determination R 2 
# petal length and petal width in cms

# Compute Pearson correlation between petal length and petal width

correlation = df["petal length (cm)"].corr(df["petal width (cm)"])

# Compute R-squared

r_squared = correlation ** 2

#To display output

print(f"Pearson correlation (r): {correlation:.4f}")
print(f"Coefficient of determination (R²): {r_squared:.4f}")
# Out:
# Pearson correlation (r): 0.9629
# Coefficient of determination (R²): 0.9271

# %%
# Re-create the plot from Task 6 and annotate it with the R 2 value

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris

# Load Iris data
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Extract variables
x = df["petal length (cm)"]
y = df["petal width (cm)"]

# Fit linear regression line (degree 1)
slope, intercept = np.polyfit(x, y, 1)
y_pred = slope * x + intercept

# Compute R²
correlation = x.corr(y)
r_squared = correlation ** 2

# Plot scatter
plt.figure(figsize=(8,6))
plt.scatter(x, y, color='purple', label="Data points")

# Plot regression line
plt.plot(x, y_pred, color='orange', label=f"Regression line")

# Add labels, title, and legend
plt.xlabel("Petal Length (cm)")
plt.ylabel("Petal Width (cm)")
plt.title("Petal Length vs Petal Width with Regression Line")
plt.legend()

# Add R² as text on plot
plt.text(x.min(), y.max() - 0.2, f"$R^2$ = {r_squared:.3f}", fontsize=12, color='black')

plt.grid(True)
plt.show()

# %% [markdown]
# Reference:
# Chatgpt- prompt-create regression line on scatter plot with these values, https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046

# %% [markdown]
# ## task 10: Too Many Features
#
# ## Use seaborn to create a pairplot of the data set.
# ## Explain, in your own words, what the pairplot depicts.

# %% [markdown]
# Reference:
#
# geeksforgeeks.org (2025) , Python – seaborn.pairplot() method [online] Available from: https://www.geeksforgeeks.org/python-seaborn-pairplot-method/ [accessed 4 May 2025].
#
# Chatgpt- prompt-use seaborn to create a pair plot of the iris data set, https://chatgpt.com/c/6813d08b-691c-8003-842d-96eadc100046
#
# Seaborn (2024) seaborn.pairplot[online] Available from: https://seaborn.pydata.org/generated/seaborn.pairplot.html [accessed 4 May 2025].

# %% [markdown]
# "seaborn.pairplot() method is used for visualizing relationships between multiple variables in a dataset. By creating a grid of scatter plots it helps to identify how different features interact with each other to identify patterns, correlations and trends in data. In this article, we will see how to implement "geekforgeeks.org

# %%
# Use seaborn to create a pairplot of the data set.

# Load Iris data
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)

# Add species names as a column
df['species'] = iris.target_names[iris.target]

# Create the pairplot
sns.pairplot(df, hue="species", palette="Set2")

# Show the plot
plt.show()

# %% [markdown]
# #Explain, in your own words, what the pairplot depicts.
#
# Setosa (green) seem to have it own distinct feature as show in the plots above, in most it is clustered of to the side, compaired to the virginica (blue) and versicolor (red) which seem to be much closer in meassurements and even overlapping in some of the plots. The visual representation of the data helps to distingush the differences in a more easily.
